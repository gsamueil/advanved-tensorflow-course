# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 999us/sample - loss: 237.1140 - y1_output_loss: 116.0913 - y2_output_loss: 119.0404 - y1_output_root_mean_squared_error: 10.8246 - y2_output_root_mean_squared_error: 10.9518 - val_loss: 73.4672 - val_y1_output_loss: 17.6056 - val_y2_output_loss: 55.4671 - val_y1_output_root_mean_squared_error: 4.2303 - val_y2_output_root_mean_squared_error: 7.4546
# Epoch 2/500
# 614/614 [==============================] - 0s 146us/sample - loss: 38.7032 - y1_output_loss: 13.8271 - y2_output_loss: 24.7596 - y1_output_root_mean_squared_error: 3.7291 - y2_output_root_mean_squared_error: 4.9796 - val_loss: 30.1055 - val_y1_output_loss: 11.1334 - val_y2_output_loss: 17.9762 - val_y1_output_root_mean_squared_error: 3.3935 - val_y2_output_root_mean_squared_error: 4.3116
# Epoch 3/500
# 614/614 [==============================] - 0s 153us/sample - loss: 24.2149 - y1_output_loss: 10.0353 - y2_output_loss: 14.1901 - y1_output_root_mean_squared_error: 3.1486 - y2_output_root_mean_squared_error: 3.7817 - val_loss: 21.2095 - val_y1_output_loss: 9.3634 - val_y2_output_loss: 11.5638 - val_y1_output_root_mean_squared_error: 3.0932 - val_y2_output_root_mean_squared_error: 3.4120
# Epoch 4/500
# 614/614 [==============================] - 0s 136us/sample - loss: 23.1498 - y1_output_loss: 9.2197 - y2_output_loss: 14.1280 - y1_output_root_mean_squared_error: 3.0109 - y2_output_root_mean_squared_error: 3.7529 - val_loss: 39.7936 - val_y1_output_loss: 15.9300 - val_y2_output_loss: 22.6525 - val_y1_output_root_mean_squared_error: 4.0545 - val_y2_output_root_mean_squared_error: 4.8327
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 24.6739 - y1_output_loss: 9.4253 - y2_output_loss: 15.1148 - y1_output_root_mean_squared_error: 3.0797 - y2_output_root_mean_squared_error: 3.8974 - val_loss: 22.2674 - val_y1_output_loss: 9.1458 - val_y2_output_loss: 12.6186 - val_y1_output_root_mean_squared_error: 3.0710 - val_y2_output_root_mean_squared_error: 3.5828
# Epoch 6/500
# 614/614 [==============================] - 0s 140us/sample - loss: 21.4047 - y1_output_loss: 8.5859 - y2_output_loss: 12.7919 - y1_output_root_mean_squared_error: 2.9322 - y2_output_root_mean_squared_error: 3.5787 - val_loss: 20.0371 - val_y1_output_loss: 8.4206 - val_y2_output_loss: 11.0426 - val_y1_output_root_mean_squared_error: 2.9466 - val_y2_output_root_mean_squared_error: 3.3697
# Epoch 7/500
# 614/614 [==============================] - 0s 142us/sample - loss: 23.6232 - y1_output_loss: 8.4858 - y2_output_loss: 15.0475 - y1_output_root_mean_squared_error: 2.9199 - y2_output_root_mean_squared_error: 3.8855 - val_loss: 23.4619 - val_y1_output_loss: 9.1401 - val_y2_output_loss: 13.7291 - val_y1_output_root_mean_squared_error: 3.0735 - val_y2_output_root_mean_squared_error: 3.7437
# Epoch 8/500
# 614/614 [==============================] - 0s 137us/sample - loss: 23.8433 - y1_output_loss: 8.6843 - y2_output_loss: 14.9914 - y1_output_root_mean_squared_error: 2.9580 - y2_output_root_mean_squared_error: 3.8850 - val_loss: 18.4964 - val_y1_output_loss: 8.3223 - val_y2_output_loss: 9.7202 - val_y1_output_root_mean_squared_error: 2.9276 - val_y2_output_root_mean_squared_error: 3.1505
# Epoch 9/500
# 614/614 [==============================] - 0s 146us/sample - loss: 20.3500 - y1_output_loss: 8.1389 - y2_output_loss: 12.4513 - y1_output_root_mean_squared_error: 2.8488 - y2_output_root_mean_squared_error: 3.4978 - val_loss: 28.5723 - val_y1_output_loss: 10.6141 - val_y2_output_loss: 17.3511 - val_y1_output_root_mean_squared_error: 3.3042 - val_y2_output_root_mean_squared_error: 4.2017
# Epoch 10/500
# 614/614 [==============================] - 0s 138us/sample - loss: 23.1617 - y1_output_loss: 8.1979 - y2_output_loss: 14.8018 - y1_output_root_mean_squared_error: 2.8754 - y2_output_root_mean_squared_error: 3.8592 - val_loss: 22.8214 - val_y1_output_loss: 10.1030 - val_y2_output_loss: 12.2007 - val_y1_output_root_mean_squared_error: 3.2219 - val_y2_output_root_mean_squared_error: 3.5271
# Epoch 11/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.2453 - y1_output_loss: 8.2889 - y2_output_loss: 14.0045 - y1_output_root_mean_squared_error: 2.8707 - y2_output_root_mean_squared_error: 3.7422 - val_loss: 21.6999 - val_y1_output_loss: 10.0670 - val_y2_output_loss: 11.0169 - val_y1_output_root_mean_squared_error: 3.2203 - val_y2_output_root_mean_squared_error: 3.3660
# Epoch 12/500
# 614/614 [==============================] - 0s 138us/sample - loss: 22.4288 - y1_output_loss: 8.4828 - y2_output_loss: 13.9296 - y1_output_root_mean_squared_error: 2.9129 - y2_output_root_mean_squared_error: 3.7341 - val_loss: 21.2931 - val_y1_output_loss: 8.6235 - val_y2_output_loss: 12.0165 - val_y1_output_root_mean_squared_error: 2.9905 - val_y2_output_root_mean_squared_error: 3.5143
# Epoch 13/500
# 614/614 [==============================] - 0s 132us/sample - loss: 18.0540 - y1_output_loss: 7.4109 - y2_output_loss: 10.5612 - y1_output_root_mean_squared_error: 2.7278 - y2_output_root_mean_squared_error: 3.2578 - val_loss: 22.7267 - val_y1_output_loss: 9.5599 - val_y2_output_loss: 12.4627 - val_y1_output_root_mean_squared_error: 3.1420 - val_y2_output_root_mean_squared_error: 3.5853
# Epoch 14/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.8349 - y1_output_loss: 7.5351 - y2_output_loss: 11.3302 - y1_output_root_mean_squared_error: 2.7509 - y2_output_root_mean_squared_error: 3.3567 - val_loss: 21.8164 - val_y1_output_loss: 8.7880 - val_y2_output_loss: 12.2671 - val_y1_output_root_mean_squared_error: 3.0176 - val_y2_output_root_mean_squared_error: 3.5652
# Epoch 15/500
# 614/614 [==============================] - 0s 138us/sample - loss: 23.6262 - y1_output_loss: 8.4031 - y2_output_loss: 15.0598 - y1_output_root_mean_squared_error: 2.9094 - y2_output_root_mean_squared_error: 3.8938 - val_loss: 18.7421 - val_y1_output_loss: 7.8982 - val_y2_output_loss: 10.1867 - val_y1_output_root_mean_squared_error: 2.8608 - val_y2_output_root_mean_squared_error: 3.2493
# Epoch 16/500
# 614/614 [==============================] - 0s 138us/sample - loss: 17.4885 - y1_output_loss: 7.1035 - y2_output_loss: 10.3305 - y1_output_root_mean_squared_error: 2.6718 - y2_output_root_mean_squared_error: 3.2171 - val_loss: 22.3642 - val_y1_output_loss: 9.0418 - val_y2_output_loss: 12.8396 - val_y1_output_root_mean_squared_error: 3.0460 - val_y2_output_root_mean_squared_error: 3.6175
# Epoch 17/500
# 614/614 [==============================] - 0s 133us/sample - loss: 21.4495 - y1_output_loss: 7.6352 - y2_output_loss: 13.7040 - y1_output_root_mean_squared_error: 2.7714 - y2_output_root_mean_squared_error: 3.7107 - val_loss: 19.6338 - val_y1_output_loss: 8.7700 - val_y2_output_loss: 10.2689 - val_y1_output_root_mean_squared_error: 3.0099 - val_y2_output_root_mean_squared_error: 3.2518
# Epoch 18/500
# 614/614 [==============================] - 0s 137us/sample - loss: 16.4331 - y1_output_loss: 6.8441 - y2_output_loss: 9.4727 - y1_output_root_mean_squared_error: 2.6224 - y2_output_root_mean_squared_error: 3.0913 - val_loss: 20.0568 - val_y1_output_loss: 8.5374 - val_y2_output_loss: 10.9139 - val_y1_output_root_mean_squared_error: 2.9677 - val_y2_output_root_mean_squared_error: 3.3540
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.6028 - y1_output_loss: 6.9565 - y2_output_loss: 11.4875 - y1_output_root_mean_squared_error: 2.6464 - y2_output_root_mean_squared_error: 3.4058 - val_loss: 16.3185 - val_y1_output_loss: 7.1737 - val_y2_output_loss: 8.6189 - val_y1_output_root_mean_squared_error: 2.7233 - val_y2_output_root_mean_squared_error: 2.9836
# Epoch 20/500
# 614/614 [==============================] - 0s 134us/sample - loss: 17.9434 - y1_output_loss: 7.0738 - y2_output_loss: 10.9235 - y1_output_root_mean_squared_error: 2.6560 - y2_output_root_mean_squared_error: 3.2998 - val_loss: 29.3096 - val_y1_output_loss: 9.2414 - val_y2_output_loss: 19.0945 - val_y1_output_root_mean_squared_error: 3.0927 - val_y2_output_root_mean_squared_error: 4.4435
# Epoch 21/500
# 614/614 [==============================] - 0s 143us/sample - loss: 17.5567 - y1_output_loss: 6.7306 - y2_output_loss: 10.7989 - y1_output_root_mean_squared_error: 2.6001 - y2_output_root_mean_squared_error: 3.2858 - val_loss: 35.5212 - val_y1_output_loss: 9.3104 - val_y2_output_loss: 25.0792 - val_y1_output_root_mean_squared_error: 3.1052 - val_y2_output_root_mean_squared_error: 5.0871
# Epoch 22/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.7630 - y1_output_loss: 6.7277 - y2_output_loss: 11.8988 - y1_output_root_mean_squared_error: 2.5990 - y2_output_root_mean_squared_error: 3.4653 - val_loss: 23.0431 - val_y1_output_loss: 8.2240 - val_y2_output_loss: 14.0935 - val_y1_output_root_mean_squared_error: 2.9157 - val_y2_output_root_mean_squared_error: 3.8134
# Epoch 23/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.4875 - y1_output_loss: 6.0972 - y2_output_loss: 10.5602 - y1_output_root_mean_squared_error: 2.4617 - y2_output_root_mean_squared_error: 3.2292 - val_loss: 15.0974 - val_y1_output_loss: 6.2337 - val_y2_output_loss: 8.4334 - val_y1_output_root_mean_squared_error: 2.5383 - val_y2_output_root_mean_squared_error: 2.9418
# Epoch 24/500
# 614/614 [==============================] - 0s 141us/sample - loss: 19.1448 - y1_output_loss: 6.8171 - y2_output_loss: 12.2950 - y1_output_root_mean_squared_error: 2.6162 - y2_output_root_mean_squared_error: 3.5072 - val_loss: 17.4704 - val_y1_output_loss: 6.0786 - val_y2_output_loss: 11.1211 - val_y1_output_root_mean_squared_error: 2.4986 - val_y2_output_root_mean_squared_error: 3.3507
# Epoch 25/500
# 614/614 [==============================] - 0s 146us/sample - loss: 14.4379 - y1_output_loss: 5.5601 - y2_output_loss: 8.9869 - y1_output_root_mean_squared_error: 2.3518 - y2_output_root_mean_squared_error: 2.9845 - val_loss: 32.5979 - val_y1_output_loss: 8.8402 - val_y2_output_loss: 22.7852 - val_y1_output_root_mean_squared_error: 3.0220 - val_y2_output_root_mean_squared_error: 4.8441
# Epoch 26/500
# 614/614 [==============================] - 0s 149us/sample - loss: 15.5117 - y1_output_loss: 5.7811 - y2_output_loss: 9.6158 - y1_output_root_mean_squared_error: 2.4117 - y2_output_root_mean_squared_error: 3.1137 - val_loss: 13.5548 - val_y1_output_loss: 5.5678 - val_y2_output_loss: 7.5161 - val_y1_output_root_mean_squared_error: 2.3995 - val_y2_output_root_mean_squared_error: 2.7924
# Epoch 27/500
# 614/614 [==============================] - 0s 196us/sample - loss: 18.0515 - y1_output_loss: 5.9956 - y2_output_loss: 12.0518 - y1_output_root_mean_squared_error: 2.4392 - y2_output_root_mean_squared_error: 3.4788 - val_loss: 15.1602 - val_y1_output_loss: 6.1342 - val_y2_output_loss: 8.4859 - val_y1_output_root_mean_squared_error: 2.5218 - val_y2_output_root_mean_squared_error: 2.9666
# Epoch 28/500
# 614/614 [==============================] - 0s 152us/sample - loss: 12.8269 - y1_output_loss: 5.0627 - y2_output_loss: 7.9620 - y1_output_root_mean_squared_error: 2.2407 - y2_output_root_mean_squared_error: 2.7940 - val_loss: 17.4704 - val_y1_output_loss: 6.8165 - val_y2_output_loss: 10.0861 - val_y1_output_root_mean_squared_error: 2.6554 - val_y2_output_root_mean_squared_error: 3.2279
# Epoch 29/500
# 614/614 [==============================] - 0s 145us/sample - loss: 12.4976 - y1_output_loss: 5.1124 - y2_output_loss: 7.7421 - y1_output_root_mean_squared_error: 2.2354 - y2_output_root_mean_squared_error: 2.7387 - val_loss: 15.5959 - val_y1_output_loss: 5.8371 - val_y2_output_loss: 9.3690 - val_y1_output_root_mean_squared_error: 2.4514 - val_y2_output_root_mean_squared_error: 3.0962
# Epoch 30/500
# 614/614 [==============================] - 0s 145us/sample - loss: 14.5890 - y1_output_loss: 5.4735 - y2_output_loss: 9.0116 - y1_output_root_mean_squared_error: 2.3448 - y2_output_root_mean_squared_error: 3.0151 - val_loss: 15.7065 - val_y1_output_loss: 5.7791 - val_y2_output_loss: 9.3880 - val_y1_output_root_mean_squared_error: 2.4472 - val_y2_output_root_mean_squared_error: 3.1173
# Epoch 31/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.9388 - y1_output_loss: 4.9694 - y2_output_loss: 8.0133 - y1_output_root_mean_squared_error: 2.2205 - y2_output_root_mean_squared_error: 2.8299 - val_loss: 21.9013 - val_y1_output_loss: 7.4533 - val_y2_output_loss: 13.7634 - val_y1_output_root_mean_squared_error: 2.7752 - val_y2_output_root_mean_squared_error: 3.7682
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.9683 - y1_output_loss: 4.9628 - y2_output_loss: 7.9536 - y1_output_root_mean_squared_error: 2.2342 - y2_output_root_mean_squared_error: 2.8243 - val_loss: 12.3811 - val_y1_output_loss: 4.8553 - val_y2_output_loss: 7.2213 - val_y1_output_root_mean_squared_error: 2.2300 - val_y2_output_root_mean_squared_error: 2.7218
# Epoch 33/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.0313 - y1_output_loss: 4.3889 - y2_output_loss: 6.5669 - y1_output_root_mean_squared_error: 2.1008 - y2_output_root_mean_squared_error: 2.5725 - val_loss: 10.5869 - val_y1_output_loss: 4.3713 - val_y2_output_loss: 5.8851 - val_y1_output_root_mean_squared_error: 2.1188 - val_y2_output_root_mean_squared_error: 2.4693
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.0108 - y1_output_loss: 4.0212 - y2_output_loss: 7.0987 - y1_output_root_mean_squared_error: 2.0047 - y2_output_root_mean_squared_error: 2.6442 - val_loss: 18.2576 - val_y1_output_loss: 5.4329 - val_y2_output_loss: 12.4839 - val_y1_output_root_mean_squared_error: 2.3569 - val_y2_output_root_mean_squared_error: 3.5641
# Epoch 35/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.6804 - y1_output_loss: 4.4065 - y2_output_loss: 7.2478 - y1_output_root_mean_squared_error: 2.1086 - y2_output_root_mean_squared_error: 2.6897 - val_loss: 11.8798 - val_y1_output_loss: 4.3587 - val_y2_output_loss: 7.3162 - val_y1_output_root_mean_squared_error: 2.1090 - val_y2_output_root_mean_squared_error: 2.7262
# Epoch 36/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.8309 - y1_output_loss: 3.9424 - y2_output_loss: 6.8570 - y1_output_root_mean_squared_error: 1.9920 - y2_output_root_mean_squared_error: 2.6197 - val_loss: 10.0608 - val_y1_output_loss: 3.7523 - val_y2_output_loss: 6.0435 - val_y1_output_root_mean_squared_error: 1.9624 - val_y2_output_root_mean_squared_error: 2.4919
# Epoch 37/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.3121 - y1_output_loss: 3.9883 - y2_output_loss: 8.2411 - y1_output_root_mean_squared_error: 2.0029 - y2_output_root_mean_squared_error: 2.8810 - val_loss: 16.5946 - val_y1_output_loss: 5.4648 - val_y2_output_loss: 10.5408 - val_y1_output_root_mean_squared_error: 2.3810 - val_y2_output_root_mean_squared_error: 3.3054
# Epoch 38/500
# 614/614 [==============================] - 0s 148us/sample - loss: 9.8314 - y1_output_loss: 3.5257 - y2_output_loss: 6.2385 - y1_output_root_mean_squared_error: 1.8822 - y2_output_root_mean_squared_error: 2.5078 - val_loss: 8.8840 - val_y1_output_loss: 3.5276 - val_y2_output_loss: 5.1089 - val_y1_output_root_mean_squared_error: 1.9027 - val_y2_output_root_mean_squared_error: 2.2943
# Epoch 39/500
# 614/614 [==============================] - 0s 152us/sample - loss: 8.2626 - y1_output_loss: 3.0880 - y2_output_loss: 5.1473 - y1_output_root_mean_squared_error: 1.7586 - y2_output_root_mean_squared_error: 2.2738 - val_loss: 12.4186 - val_y1_output_loss: 5.0000 - val_y2_output_loss: 7.3060 - val_y1_output_root_mean_squared_error: 2.2418 - val_y2_output_root_mean_squared_error: 2.7190
# Epoch 40/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.8269 - y1_output_loss: 3.5191 - y2_output_loss: 6.3701 - y1_output_root_mean_squared_error: 1.8666 - y2_output_root_mean_squared_error: 2.5185 - val_loss: 27.2453 - val_y1_output_loss: 8.8423 - val_y2_output_loss: 18.1986 - val_y1_output_root_mean_squared_error: 2.9789 - val_y2_output_root_mean_squared_error: 4.2862
# Epoch 41/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.1019 - y1_output_loss: 3.5561 - y2_output_loss: 7.4692 - y1_output_root_mean_squared_error: 1.8897 - y2_output_root_mean_squared_error: 2.7442 - val_loss: 7.7491 - val_y1_output_loss: 2.8716 - val_y2_output_loss: 4.7260 - val_y1_output_root_mean_squared_error: 1.7067 - val_y2_output_root_mean_squared_error: 2.1991
# Epoch 42/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.9303 - y1_output_loss: 2.7528 - y2_output_loss: 5.2917 - y1_output_root_mean_squared_error: 1.6497 - y2_output_root_mean_squared_error: 2.2823 - val_loss: 23.2244 - val_y1_output_loss: 5.6503 - val_y2_output_loss: 16.9813 - val_y1_output_root_mean_squared_error: 2.4081 - val_y2_output_root_mean_squared_error: 4.1744
# Epoch 43/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.9623 - y1_output_loss: 3.1948 - y2_output_loss: 5.7864 - y1_output_root_mean_squared_error: 1.7898 - y2_output_root_mean_squared_error: 2.3998 - val_loss: 7.0583 - val_y1_output_loss: 2.7328 - val_y2_output_loss: 4.0991 - val_y1_output_root_mean_squared_error: 1.6787 - val_y2_output_root_mean_squared_error: 2.0592
# Epoch 44/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.2607 - y1_output_loss: 2.9857 - y2_output_loss: 6.2133 - y1_output_root_mean_squared_error: 1.7329 - y2_output_root_mean_squared_error: 2.5015 - val_loss: 8.1353 - val_y1_output_loss: 2.6811 - val_y2_output_loss: 5.2466 - val_y1_output_root_mean_squared_error: 1.6489 - val_y2_output_root_mean_squared_error: 2.3273
# Epoch 45/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.3963 - y1_output_loss: 2.6227 - y2_output_loss: 4.7444 - y1_output_root_mean_squared_error: 1.6219 - y2_output_root_mean_squared_error: 2.1830 - val_loss: 10.5499 - val_y1_output_loss: 3.5774 - val_y2_output_loss: 6.6627 - val_y1_output_root_mean_squared_error: 1.9169 - val_y2_output_root_mean_squared_error: 2.6221
# Epoch 46/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.6780 - y1_output_loss: 2.3456 - y2_output_loss: 4.3057 - y1_output_root_mean_squared_error: 1.5352 - y2_output_root_mean_squared_error: 2.0788 - val_loss: 15.9645 - val_y1_output_loss: 4.3698 - val_y2_output_loss: 11.4254 - val_y1_output_root_mean_squared_error: 2.0991 - val_y2_output_root_mean_squared_error: 3.3997
# Epoch 47/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.1815 - y1_output_loss: 2.7067 - y2_output_loss: 5.5411 - y1_output_root_mean_squared_error: 1.6436 - y2_output_root_mean_squared_error: 2.3410 - val_loss: 18.1131 - val_y1_output_loss: 3.4839 - val_y2_output_loss: 14.1191 - val_y1_output_root_mean_squared_error: 1.8992 - val_y2_output_root_mean_squared_error: 3.8087
# Epoch 48/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.7400 - y1_output_loss: 3.1011 - y2_output_loss: 6.5764 - y1_output_root_mean_squared_error: 1.7679 - y2_output_root_mean_squared_error: 2.5719 - val_loss: 6.4546 - val_y1_output_loss: 2.5942 - val_y2_output_loss: 3.7320 - val_y1_output_root_mean_squared_error: 1.6323 - val_y2_output_root_mean_squared_error: 1.9468
# Epoch 49/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.4474 - y1_output_loss: 2.4843 - y2_output_loss: 5.9590 - y1_output_root_mean_squared_error: 1.5736 - y2_output_root_mean_squared_error: 2.4436 - val_loss: 8.7963 - val_y1_output_loss: 2.7164 - val_y2_output_loss: 5.8155 - val_y1_output_root_mean_squared_error: 1.6740 - val_y2_output_root_mean_squared_error: 2.4483
# Epoch 50/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.6808 - y1_output_loss: 2.1680 - y2_output_loss: 4.4726 - y1_output_root_mean_squared_error: 1.4794 - y2_output_root_mean_squared_error: 2.1195 - val_loss: 6.4410 - val_y1_output_loss: 2.5190 - val_y2_output_loss: 3.7404 - val_y1_output_root_mean_squared_error: 1.6113 - val_y2_output_root_mean_squared_error: 1.9608
# Epoch 51/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.0990 - y1_output_loss: 2.5234 - y2_output_loss: 5.6079 - y1_output_root_mean_squared_error: 1.5817 - y2_output_root_mean_squared_error: 2.3658 - val_loss: 6.4015 - val_y1_output_loss: 2.3992 - val_y2_output_loss: 3.8255 - val_y1_output_root_mean_squared_error: 1.5740 - val_y2_output_root_mean_squared_error: 1.9809
# Epoch 52/500
# 614/614 [==============================] - 0s 162us/sample - loss: 6.6143 - y1_output_loss: 2.2750 - y2_output_loss: 4.2840 - y1_output_root_mean_squared_error: 1.5128 - y2_output_root_mean_squared_error: 2.0798 - val_loss: 7.3185 - val_y1_output_loss: 2.4716 - val_y2_output_loss: 4.7317 - val_y1_output_root_mean_squared_error: 1.5808 - val_y2_output_root_mean_squared_error: 2.1953
# Epoch 53/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.9824 - y1_output_loss: 2.1025 - y2_output_loss: 3.8909 - y1_output_root_mean_squared_error: 1.4544 - y2_output_root_mean_squared_error: 1.9665 - val_loss: 6.2873 - val_y1_output_loss: 2.3402 - val_y2_output_loss: 3.7799 - val_y1_output_root_mean_squared_error: 1.5408 - val_y2_output_root_mean_squared_error: 1.9782
# Epoch 54/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.5604 - y1_output_loss: 2.1664 - y2_output_loss: 4.5077 - y1_output_root_mean_squared_error: 1.4657 - y2_output_root_mean_squared_error: 2.1005 - val_loss: 24.0660 - val_y1_output_loss: 7.1697 - val_y2_output_loss: 16.2112 - val_y1_output_root_mean_squared_error: 2.7145 - val_y2_output_root_mean_squared_error: 4.0863
# Epoch 55/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.5948 - y1_output_loss: 2.1324 - y2_output_loss: 5.5127 - y1_output_root_mean_squared_error: 1.4629 - y2_output_root_mean_squared_error: 2.3355 - val_loss: 24.3206 - val_y1_output_loss: 4.7279 - val_y2_output_loss: 19.4044 - val_y1_output_root_mean_squared_error: 2.1739 - val_y2_output_root_mean_squared_error: 4.4266
# Epoch 56/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.6559 - y1_output_loss: 1.9943 - y2_output_loss: 4.6289 - y1_output_root_mean_squared_error: 1.4175 - y2_output_root_mean_squared_error: 2.1556 - val_loss: 6.2140 - val_y1_output_loss: 2.1723 - val_y2_output_loss: 3.9763 - val_y1_output_root_mean_squared_error: 1.4774 - val_y2_output_root_mean_squared_error: 2.0078
# Epoch 57/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.9345 - y1_output_loss: 2.5213 - y2_output_loss: 6.3679 - y1_output_root_mean_squared_error: 1.5853 - y2_output_root_mean_squared_error: 2.5340 - val_loss: 6.0993 - val_y1_output_loss: 2.4924 - val_y2_output_loss: 3.5064 - val_y1_output_root_mean_squared_error: 1.5847 - val_y2_output_root_mean_squared_error: 1.8942
# Epoch 58/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.8405 - y1_output_loss: 2.5149 - y2_output_loss: 5.2834 - y1_output_root_mean_squared_error: 1.5886 - y2_output_root_mean_squared_error: 2.3058 - val_loss: 8.1530 - val_y1_output_loss: 2.5831 - val_y2_output_loss: 5.3005 - val_y1_output_root_mean_squared_error: 1.6330 - val_y2_output_root_mean_squared_error: 2.3423
# Epoch 59/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.4235 - y1_output_loss: 2.6274 - y2_output_loss: 5.7601 - y1_output_root_mean_squared_error: 1.6263 - y2_output_root_mean_squared_error: 2.4038 - val_loss: 11.0433 - val_y1_output_loss: 3.4638 - val_y2_output_loss: 7.5069 - val_y1_output_root_mean_squared_error: 1.8614 - val_y2_output_root_mean_squared_error: 2.7529
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.5455 - y1_output_loss: 1.8368 - y2_output_loss: 3.7246 - y1_output_root_mean_squared_error: 1.3575 - y2_output_root_mean_squared_error: 1.9242 - val_loss: 5.6460 - val_y1_output_loss: 2.0332 - val_y2_output_loss: 3.4457 - val_y1_output_root_mean_squared_error: 1.4514 - val_y2_output_root_mean_squared_error: 1.8813
# Epoch 61/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.6634 - y1_output_loss: 1.7523 - y2_output_loss: 3.8701 - y1_output_root_mean_squared_error: 1.3297 - y2_output_root_mean_squared_error: 1.9737 - val_loss: 5.1799 - val_y1_output_loss: 1.7448 - val_y2_output_loss: 3.2774 - val_y1_output_root_mean_squared_error: 1.3355 - val_y2_output_root_mean_squared_error: 1.8430
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.3988 - y1_output_loss: 2.1617 - y2_output_loss: 4.2092 - y1_output_root_mean_squared_error: 1.4695 - y2_output_root_mean_squared_error: 2.0589 - val_loss: 5.1988 - val_y1_output_loss: 1.6391 - val_y2_output_loss: 3.3984 - val_y1_output_root_mean_squared_error: 1.2934 - val_y2_output_root_mean_squared_error: 1.8778
# Epoch 63/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.4217 - y1_output_loss: 1.5642 - y2_output_loss: 3.8871 - y1_output_root_mean_squared_error: 1.2509 - y2_output_root_mean_squared_error: 1.9639 - val_loss: 13.9813 - val_y1_output_loss: 4.0487 - val_y2_output_loss: 9.6810 - val_y1_output_root_mean_squared_error: 2.0344 - val_y2_output_root_mean_squared_error: 3.1373
# Epoch 64/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.6195 - y1_output_loss: 1.7160 - y2_output_loss: 3.8647 - y1_output_root_mean_squared_error: 1.3148 - y2_output_root_mean_squared_error: 1.9725 - val_loss: 5.9169 - val_y1_output_loss: 1.9399 - val_y2_output_loss: 3.7949 - val_y1_output_root_mean_squared_error: 1.4158 - val_y2_output_root_mean_squared_error: 1.9780
# Epoch 65/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.2446 - y1_output_loss: 1.8917 - y2_output_loss: 4.3876 - y1_output_root_mean_squared_error: 1.3788 - y2_output_root_mean_squared_error: 2.0841 - val_loss: 11.1572 - val_y1_output_loss: 2.5749 - val_y2_output_loss: 8.4340 - val_y1_output_root_mean_squared_error: 1.6128 - val_y2_output_root_mean_squared_error: 2.9251
# Epoch 66/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.4653 - y1_output_loss: 1.6073 - y2_output_loss: 3.8117 - y1_output_root_mean_squared_error: 1.2733 - y2_output_root_mean_squared_error: 1.9606 - val_loss: 3.9267 - val_y1_output_loss: 1.3472 - val_y2_output_loss: 2.4546 - val_y1_output_root_mean_squared_error: 1.1798 - val_y2_output_root_mean_squared_error: 1.5921
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.2546 - y1_output_loss: 1.2663 - y2_output_loss: 2.9584 - y1_output_root_mean_squared_error: 1.1298 - y2_output_root_mean_squared_error: 1.7257 - val_loss: 6.1745 - val_y1_output_loss: 2.0222 - val_y2_output_loss: 4.0101 - val_y1_output_root_mean_squared_error: 1.4368 - val_y2_output_root_mean_squared_error: 2.0274
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.1634 - y1_output_loss: 1.1803 - y2_output_loss: 2.9468 - y1_output_root_mean_squared_error: 1.0909 - y2_output_root_mean_squared_error: 1.7243 - val_loss: 3.5181 - val_y1_output_loss: 1.2154 - val_y2_output_loss: 2.1849 - val_y1_output_root_mean_squared_error: 1.1221 - val_y2_output_root_mean_squared_error: 1.5030
# Epoch 69/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5179 - y1_output_loss: 1.0872 - y2_output_loss: 2.4321 - y1_output_root_mean_squared_error: 1.0449 - y2_output_root_mean_squared_error: 1.5575 - val_loss: 6.8669 - val_y1_output_loss: 2.1636 - val_y2_output_loss: 4.7106 - val_y1_output_root_mean_squared_error: 1.4593 - val_y2_output_root_mean_squared_error: 2.1766
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.6541 - y1_output_loss: 1.3549 - y2_output_loss: 3.2831 - y1_output_root_mean_squared_error: 1.1648 - y2_output_root_mean_squared_error: 1.8159 - val_loss: 5.0955 - val_y1_output_loss: 1.6087 - val_y2_output_loss: 3.3749 - val_y1_output_root_mean_squared_error: 1.2762 - val_y2_output_root_mean_squared_error: 1.8619
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5536 - y1_output_loss: 1.2234 - y2_output_loss: 3.3193 - y1_output_root_mean_squared_error: 1.1001 - y2_output_root_mean_squared_error: 1.8285 - val_loss: 4.1099 - val_y1_output_loss: 1.5051 - val_y2_output_loss: 2.5635 - val_y1_output_root_mean_squared_error: 1.2234 - val_y2_output_root_mean_squared_error: 1.6165
# Epoch 72/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9994 - y1_output_loss: 1.1514 - y2_output_loss: 2.8200 - y1_output_root_mean_squared_error: 1.0771 - y2_output_root_mean_squared_error: 1.6850 - val_loss: 4.9628 - val_y1_output_loss: 1.5815 - val_y2_output_loss: 3.2384 - val_y1_output_root_mean_squared_error: 1.2703 - val_y2_output_root_mean_squared_error: 1.8301
# Epoch 73/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.6976 - y1_output_loss: 0.9638 - y2_output_loss: 2.7311 - y1_output_root_mean_squared_error: 0.9831 - y2_output_root_mean_squared_error: 1.6526 - val_loss: 4.9634 - val_y1_output_loss: 1.0281 - val_y2_output_loss: 3.7862 - val_y1_output_root_mean_squared_error: 1.0329 - val_y2_output_root_mean_squared_error: 1.9740
# Epoch 74/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.5977 - y1_output_loss: 1.3908 - y2_output_loss: 4.1789 - y1_output_root_mean_squared_error: 1.1847 - y2_output_root_mean_squared_error: 2.0480 - val_loss: 3.9131 - val_y1_output_loss: 1.1417 - val_y2_output_loss: 2.6754 - val_y1_output_root_mean_squared_error: 1.0693 - val_y2_output_root_mean_squared_error: 1.6642
# Epoch 75/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9054 - y1_output_loss: 1.0584 - y2_output_loss: 2.8199 - y1_output_root_mean_squared_error: 1.0298 - y2_output_root_mean_squared_error: 1.6867 - val_loss: 3.3123 - val_y1_output_loss: 1.1666 - val_y2_output_loss: 2.0787 - val_y1_output_root_mean_squared_error: 1.0851 - val_y2_output_root_mean_squared_error: 1.4611
# Epoch 76/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.1225 - y1_output_loss: 1.3477 - y2_output_loss: 3.7787 - y1_output_root_mean_squared_error: 1.1617 - y2_output_root_mean_squared_error: 1.9424 - val_loss: 5.1712 - val_y1_output_loss: 1.5541 - val_y2_output_loss: 3.7472 - val_y1_output_root_mean_squared_error: 1.2277 - val_y2_output_root_mean_squared_error: 1.9141
# Epoch 77/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8265 - y1_output_loss: 0.9696 - y2_output_loss: 2.8572 - y1_output_root_mean_squared_error: 0.9756 - y2_output_root_mean_squared_error: 1.6955 - val_loss: 13.3654 - val_y1_output_loss: 3.9776 - val_y2_output_loss: 9.0235 - val_y1_output_root_mean_squared_error: 2.0240 - val_y2_output_root_mean_squared_error: 3.0445
# Epoch 78/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3178 - y1_output_loss: 0.7764 - y2_output_loss: 2.5301 - y1_output_root_mean_squared_error: 0.8849 - y2_output_root_mean_squared_error: 1.5921 - val_loss: 4.5491 - val_y1_output_loss: 1.0109 - val_y2_output_loss: 3.4128 - val_y1_output_root_mean_squared_error: 1.0217 - val_y2_output_root_mean_squared_error: 1.8722
# Epoch 79/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6405 - y1_output_loss: 0.6824 - y2_output_loss: 1.9350 - y1_output_root_mean_squared_error: 0.8294 - y2_output_root_mean_squared_error: 1.3974 - val_loss: 3.5763 - val_y1_output_loss: 1.0104 - val_y2_output_loss: 2.4972 - val_y1_output_root_mean_squared_error: 1.0108 - val_y2_output_root_mean_squared_error: 1.5983
# Epoch 80/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9119 - y1_output_loss: 1.0482 - y2_output_loss: 2.8366 - y1_output_root_mean_squared_error: 1.0274 - y2_output_root_mean_squared_error: 1.6901 - val_loss: 3.4255 - val_y1_output_loss: 1.1359 - val_y2_output_loss: 2.2051 - val_y1_output_root_mean_squared_error: 1.0783 - val_y2_output_root_mean_squared_error: 1.5043
# Epoch 81/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.2675 - y1_output_loss: 0.9939 - y2_output_loss: 3.2811 - y1_output_root_mean_squared_error: 0.9941 - y2_output_root_mean_squared_error: 1.8108 - val_loss: 5.9167 - val_y1_output_loss: 1.2090 - val_y2_output_loss: 4.5520 - val_y1_output_root_mean_squared_error: 1.1164 - val_y2_output_root_mean_squared_error: 2.1611
# Epoch 82/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3464 - y1_output_loss: 0.8183 - y2_output_loss: 2.5035 - y1_output_root_mean_squared_error: 0.9071 - y2_output_root_mean_squared_error: 1.5886 - val_loss: 3.0474 - val_y1_output_loss: 0.9289 - val_y2_output_loss: 2.0983 - val_y1_output_root_mean_squared_error: 0.9632 - val_y2_output_root_mean_squared_error: 1.4559
# Epoch 83/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.1255 - y1_output_loss: 0.7686 - y2_output_loss: 2.3406 - y1_output_root_mean_squared_error: 0.8774 - y2_output_root_mean_squared_error: 1.5348 - val_loss: 2.6658 - val_y1_output_loss: 0.6979 - val_y2_output_loss: 1.8806 - val_y1_output_root_mean_squared_error: 0.8493 - val_y2_output_root_mean_squared_error: 1.3944
# Epoch 84/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.3425 - y1_output_loss: 1.0885 - y2_output_loss: 3.2284 - y1_output_root_mean_squared_error: 1.0447 - y2_output_root_mean_squared_error: 1.8031 - val_loss: 2.7928 - val_y1_output_loss: 0.7843 - val_y2_output_loss: 1.9477 - val_y1_output_root_mean_squared_error: 0.8977 - val_y2_output_root_mean_squared_error: 1.4096
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5777 - y1_output_loss: 0.8010 - y2_output_loss: 2.7512 - y1_output_root_mean_squared_error: 0.8992 - y2_output_root_mean_squared_error: 1.6641 - val_loss: 4.7182 - val_y1_output_loss: 1.1288 - val_y2_output_loss: 3.5618 - val_y1_output_root_mean_squared_error: 1.0601 - val_y2_output_root_mean_squared_error: 1.8959
# Epoch 86/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.0177 - y1_output_loss: 1.1999 - y2_output_loss: 3.8205 - y1_output_root_mean_squared_error: 1.0889 - y2_output_root_mean_squared_error: 1.9576 - val_loss: 19.7802 - val_y1_output_loss: 5.5959 - val_y2_output_loss: 13.8585 - val_y1_output_root_mean_squared_error: 2.3867 - val_y2_output_root_mean_squared_error: 3.7528
# Epoch 87/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.9190 - y1_output_loss: 1.2300 - y2_output_loss: 2.6631 - y1_output_root_mean_squared_error: 1.1114 - y2_output_root_mean_squared_error: 1.6382 - val_loss: 3.8810 - val_y1_output_loss: 0.6737 - val_y2_output_loss: 3.0990 - val_y1_output_root_mean_squared_error: 0.8343 - val_y2_output_root_mean_squared_error: 1.7847
# Epoch 88/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8020 - y1_output_loss: 0.7569 - y2_output_loss: 2.0336 - y1_output_root_mean_squared_error: 0.8736 - y2_output_root_mean_squared_error: 1.4278 - val_loss: 3.4979 - val_y1_output_loss: 0.8980 - val_y2_output_loss: 2.4919 - val_y1_output_root_mean_squared_error: 0.9585 - val_y2_output_root_mean_squared_error: 1.6060
# Epoch 89/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5147 - y1_output_loss: 0.6281 - y2_output_loss: 1.8870 - y1_output_root_mean_squared_error: 0.7950 - y2_output_root_mean_squared_error: 1.3721 - val_loss: 2.7573 - val_y1_output_loss: 0.7208 - val_y2_output_loss: 1.9439 - val_y1_output_root_mean_squared_error: 0.8610 - val_y2_output_root_mean_squared_error: 1.4199
# Epoch 90/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5590 - y1_output_loss: 0.6467 - y2_output_loss: 1.9158 - y1_output_root_mean_squared_error: 0.8075 - y2_output_root_mean_squared_error: 1.3809 - val_loss: 5.5380 - val_y1_output_loss: 1.3114 - val_y2_output_loss: 4.1145 - val_y1_output_root_mean_squared_error: 1.1540 - val_y2_output_root_mean_squared_error: 2.0509
# Epoch 91/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3176 - y1_output_loss: 0.7723 - y2_output_loss: 2.5363 - y1_output_root_mean_squared_error: 0.8784 - y2_output_root_mean_squared_error: 1.5956 - val_loss: 3.1999 - val_y1_output_loss: 0.9345 - val_y2_output_loss: 2.2017 - val_y1_output_root_mean_squared_error: 0.9768 - val_y2_output_root_mean_squared_error: 1.4986
# Epoch 92/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6215 - y1_output_loss: 0.6876 - y2_output_loss: 1.9370 - y1_output_root_mean_squared_error: 0.8302 - y2_output_root_mean_squared_error: 1.3901 - val_loss: 5.1132 - val_y1_output_loss: 1.5893 - val_y2_output_loss: 3.5404 - val_y1_output_root_mean_squared_error: 1.2552 - val_y2_output_root_mean_squared_error: 1.8809
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8227 - y1_output_loss: 1.0549 - y2_output_loss: 2.7691 - y1_output_root_mean_squared_error: 1.0305 - y2_output_root_mean_squared_error: 1.6615 - val_loss: 3.6343 - val_y1_output_loss: 0.9547 - val_y2_output_loss: 2.5890 - val_y1_output_root_mean_squared_error: 0.9843 - val_y2_output_root_mean_squared_error: 1.6326
# Epoch 94/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1158 - y1_output_loss: 0.8144 - y2_output_loss: 2.3078 - y1_output_root_mean_squared_error: 0.9027 - y2_output_root_mean_squared_error: 1.5169 - val_loss: 9.4877 - val_y1_output_loss: 3.1137 - val_y2_output_loss: 6.2901 - val_y1_output_root_mean_squared_error: 1.7668 - val_y2_output_root_mean_squared_error: 2.5231
# Epoch 95/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.5962 - y1_output_loss: 0.5985 - y2_output_loss: 2.0020 - y1_output_root_mean_squared_error: 0.7700 - y2_output_root_mean_squared_error: 1.4153 - val_loss: 4.6828 - val_y1_output_loss: 1.1491 - val_y2_output_loss: 3.4844 - val_y1_output_root_mean_squared_error: 1.0817 - val_y2_output_root_mean_squared_error: 1.8742
# Epoch 96/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.4590 - y1_output_loss: 0.5748 - y2_output_loss: 1.8777 - y1_output_root_mean_squared_error: 0.7548 - y2_output_root_mean_squared_error: 1.3745 - val_loss: 3.3427 - val_y1_output_loss: 1.1520 - val_y2_output_loss: 2.0914 - val_y1_output_root_mean_squared_error: 1.0865 - val_y2_output_root_mean_squared_error: 1.4704
# Epoch 97/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3037 - y1_output_loss: 0.5506 - y2_output_loss: 1.7423 - y1_output_root_mean_squared_error: 0.7430 - y2_output_root_mean_squared_error: 1.3235 - val_loss: 2.7041 - val_y1_output_loss: 0.6641 - val_y2_output_loss: 1.9701 - val_y1_output_root_mean_squared_error: 0.8180 - val_y2_output_root_mean_squared_error: 1.4265
# Epoch 98/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0375 - y1_output_loss: 0.7917 - y2_output_loss: 2.2268 - y1_output_root_mean_squared_error: 0.8895 - y2_output_root_mean_squared_error: 1.4988 - val_loss: 3.1089 - val_y1_output_loss: 1.0801 - val_y2_output_loss: 1.9499 - val_y1_output_root_mean_squared_error: 1.0464 - val_y2_output_root_mean_squared_error: 1.4192
# Epoch 99/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.9785 - y1_output_loss: 0.9654 - y2_output_loss: 2.9879 - y1_output_root_mean_squared_error: 0.9858 - y2_output_root_mean_squared_error: 1.7340 - val_loss: 3.9855 - val_y1_output_loss: 1.1676 - val_y2_output_loss: 2.8463 - val_y1_output_root_mean_squared_error: 1.0760 - val_y2_output_root_mean_squared_error: 1.6816
# Epoch 100/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0556 - y1_output_loss: 0.7015 - y2_output_loss: 2.3327 - y1_output_root_mean_squared_error: 0.8393 - y2_output_root_mean_squared_error: 1.5333 - val_loss: 2.3676 - val_y1_output_loss: 0.5887 - val_y2_output_loss: 1.7374 - val_y1_output_root_mean_squared_error: 0.7720 - val_y2_output_root_mean_squared_error: 1.3310
# Epoch 101/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6130 - y1_output_loss: 0.6492 - y2_output_loss: 1.9493 - y1_output_root_mean_squared_error: 0.8084 - y2_output_root_mean_squared_error: 1.3998 - val_loss: 3.2434 - val_y1_output_loss: 0.6583 - val_y2_output_loss: 2.5000 - val_y1_output_root_mean_squared_error: 0.8189 - val_y2_output_root_mean_squared_error: 1.6040
# Epoch 102/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.7504 - y1_output_loss: 1.4118 - y2_output_loss: 3.3220 - y1_output_root_mean_squared_error: 1.1897 - y2_output_root_mean_squared_error: 1.8262 - val_loss: 4.0724 - val_y1_output_loss: 0.8417 - val_y2_output_loss: 3.2020 - val_y1_output_root_mean_squared_error: 0.9251 - val_y2_output_root_mean_squared_error: 1.7935
# Epoch 103/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.3357 - y1_output_loss: 0.5437 - y2_output_loss: 1.7731 - y1_output_root_mean_squared_error: 0.7404 - y2_output_root_mean_squared_error: 1.3370 - val_loss: 2.3190 - val_y1_output_loss: 0.4773 - val_y2_output_loss: 1.7806 - val_y1_output_root_mean_squared_error: 0.7014 - val_y2_output_root_mean_squared_error: 1.3517
# Epoch 104/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.5503 - y1_output_loss: 0.5473 - y2_output_loss: 1.9931 - y1_output_root_mean_squared_error: 0.7367 - y2_output_root_mean_squared_error: 1.4169 - val_loss: 2.1499 - val_y1_output_loss: 0.5940 - val_y2_output_loss: 1.5083 - val_y1_output_root_mean_squared_error: 0.7819 - val_y2_output_root_mean_squared_error: 1.2404
# Epoch 105/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.5471 - y1_output_loss: 0.5711 - y2_output_loss: 1.9660 - y1_output_root_mean_squared_error: 0.7517 - y2_output_root_mean_squared_error: 1.4078 - val_loss: 2.2513 - val_y1_output_loss: 0.6780 - val_y2_output_loss: 1.5132 - val_y1_output_root_mean_squared_error: 0.8290 - val_y2_output_root_mean_squared_error: 1.2507
# Epoch 106/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.1045 - y1_output_loss: 0.4539 - y2_output_loss: 1.6413 - y1_output_root_mean_squared_error: 0.6743 - y2_output_root_mean_squared_error: 1.2844 - val_loss: 2.8429 - val_y1_output_loss: 0.7747 - val_y2_output_loss: 2.0009 - val_y1_output_root_mean_squared_error: 0.8805 - val_y2_output_root_mean_squared_error: 1.4379
# Epoch 107/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.0027 - y1_output_loss: 0.4129 - y2_output_loss: 1.5786 - y1_output_root_mean_squared_error: 0.6439 - y2_output_root_mean_squared_error: 1.2602 - val_loss: 2.2746 - val_y1_output_loss: 0.5833 - val_y2_output_loss: 1.6424 - val_y1_output_root_mean_squared_error: 0.7640 - val_y2_output_root_mean_squared_error: 1.3004
# Epoch 108/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.3013 - y1_output_loss: 0.4843 - y2_output_loss: 1.8274 - y1_output_root_mean_squared_error: 0.6992 - y2_output_root_mean_squared_error: 1.3463 - val_loss: 6.5976 - val_y1_output_loss: 1.2138 - val_y2_output_loss: 5.2349 - val_y1_output_root_mean_squared_error: 1.1106 - val_y2_output_root_mean_squared_error: 2.3161
# Epoch 109/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.3218 - y1_output_loss: 0.5115 - y2_output_loss: 1.7949 - y1_output_root_mean_squared_error: 0.7179 - y2_output_root_mean_squared_error: 1.3440 - val_loss: 2.0617 - val_y1_output_loss: 0.6254 - val_y2_output_loss: 1.3760 - val_y1_output_root_mean_squared_error: 0.7994 - val_y2_output_root_mean_squared_error: 1.1928
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.0537 - y1_output_loss: 0.4691 - y2_output_loss: 1.5868 - y1_output_root_mean_squared_error: 0.6861 - y2_output_root_mean_squared_error: 1.2582 - val_loss: 3.3532 - val_y1_output_loss: 1.1737 - val_y2_output_loss: 2.1556 - val_y1_output_root_mean_squared_error: 1.0728 - val_y2_output_root_mean_squared_error: 1.4840
# Epoch 111/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.1584 - y1_output_loss: 2.0315 - y2_output_loss: 6.0527 - y1_output_root_mean_squared_error: 1.4312 - y2_output_root_mean_squared_error: 2.4719 - val_loss: 2.5680 - val_y1_output_loss: 0.7356 - val_y2_output_loss: 1.7725 - val_y1_output_root_mean_squared_error: 0.8645 - val_y2_output_root_mean_squared_error: 1.3493
# Epoch 112/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.9996 - y1_output_loss: 0.4396 - y2_output_loss: 1.6209 - y1_output_root_mean_squared_error: 0.6641 - y2_output_root_mean_squared_error: 1.2484 - val_loss: 6.3913 - val_y1_output_loss: 0.9116 - val_y2_output_loss: 5.3880 - val_y1_output_root_mean_squared_error: 0.9598 - val_y2_output_root_mean_squared_error: 2.3388
# Epoch 113/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4515 - y1_output_loss: 0.5344 - y2_output_loss: 1.9227 - y1_output_root_mean_squared_error: 0.7223 - y2_output_root_mean_squared_error: 1.3892 - val_loss: 6.3035 - val_y1_output_loss: 1.6130 - val_y2_output_loss: 4.6753 - val_y1_output_root_mean_squared_error: 1.2754 - val_y2_output_root_mean_squared_error: 2.1626
# Epoch 114/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2232 - y1_output_loss: 0.4410 - y2_output_loss: 1.7875 - y1_output_root_mean_squared_error: 0.6600 - y2_output_root_mean_squared_error: 1.3370 - val_loss: 6.3965 - val_y1_output_loss: 1.5236 - val_y2_output_loss: 4.7230 - val_y1_output_root_mean_squared_error: 1.2460 - val_y2_output_root_mean_squared_error: 2.2009
# Epoch 115/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.8206 - y1_output_loss: 0.5658 - y2_output_loss: 2.2646 - y1_output_root_mean_squared_error: 0.7526 - y2_output_root_mean_squared_error: 1.5014 - val_loss: 4.7145 - val_y1_output_loss: 0.8641 - val_y2_output_loss: 3.7555 - val_y1_output_root_mean_squared_error: 0.9348 - val_y2_output_root_mean_squared_error: 1.9597
# Epoch 116/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1181 - y1_output_loss: 0.4407 - y2_output_loss: 1.6639 - y1_output_root_mean_squared_error: 0.6656 - y2_output_root_mean_squared_error: 1.2943 - val_loss: 2.8221 - val_y1_output_loss: 0.7591 - val_y2_output_loss: 2.0013 - val_y1_output_root_mean_squared_error: 0.8731 - val_y2_output_root_mean_squared_error: 1.4352
# Epoch 117/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.9665 - y1_output_loss: 0.7949 - y2_output_loss: 2.3071 - y1_output_root_mean_squared_error: 0.8441 - y2_output_root_mean_squared_error: 1.5013 - val_loss: 28.1646 - val_y1_output_loss: 8.6753 - val_y2_output_loss: 19.3294 - val_y1_output_root_mean_squared_error: 2.9531 - val_y2_output_root_mean_squared_error: 4.4095
# Epoch 118/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.6523 - y1_output_loss: 1.2874 - y2_output_loss: 3.3841 - y1_output_root_mean_squared_error: 1.1243 - y2_output_root_mean_squared_error: 1.8407 - val_loss: 15.4500 - val_y1_output_loss: 2.9032 - val_y2_output_loss: 12.2038 - val_y1_output_root_mean_squared_error: 1.7299 - val_y2_output_root_mean_squared_error: 3.5295
# Epoch 119/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.1645 - y1_output_loss: 0.5626 - y2_output_loss: 1.6580 - y1_output_root_mean_squared_error: 0.7499 - y2_output_root_mean_squared_error: 1.2658 - val_loss: 3.5444 - val_y1_output_loss: 0.5650 - val_y2_output_loss: 2.9049 - val_y1_output_root_mean_squared_error: 0.7593 - val_y2_output_root_mean_squared_error: 1.7228
# Epoch 120/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.7841 - y1_output_loss: 0.3674 - y2_output_loss: 1.4019 - y1_output_root_mean_squared_error: 0.6081 - y2_output_root_mean_squared_error: 1.1892 - val_loss: 1.9548 - val_y1_output_loss: 0.4967 - val_y2_output_loss: 1.4123 - val_y1_output_root_mean_squared_error: 0.7149 - val_y2_output_root_mean_squared_error: 1.2015
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3270 - y1_output_loss: 0.1106 - y2_output_loss: 0.2204 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.4662 - val_loss: 0.6403 - val_y1_output_loss: 0.2242 - val_y2_output_loss: 0.4023 - val_y1_output_root_mean_squared_error: 0.4753 - val_y2_output_root_mean_squared_error: 0.6437
# Epoch 462/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4418 - y1_output_loss: 0.1333 - y2_output_loss: 0.3073 - y1_output_root_mean_squared_error: 0.3656 - y2_output_root_mean_squared_error: 0.5551 - val_loss: 0.7945 - val_y1_output_loss: 0.2462 - val_y2_output_loss: 0.5362 - val_y1_output_root_mean_squared_error: 0.5031 - val_y2_output_root_mean_squared_error: 0.7358
# Epoch 463/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3884 - y1_output_loss: 0.1330 - y2_output_loss: 0.2532 - y1_output_root_mean_squared_error: 0.3656 - y2_output_root_mean_squared_error: 0.5048 - val_loss: 0.5881 - val_y1_output_loss: 0.1850 - val_y2_output_loss: 0.3894 - val_y1_output_root_mean_squared_error: 0.4325 - val_y2_output_root_mean_squared_error: 0.6333
# Epoch 464/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2996 - y1_output_loss: 0.1132 - y2_output_loss: 0.1887 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.4342 - val_loss: 0.8596 - val_y1_output_loss: 0.3088 - val_y2_output_loss: 0.5301 - val_y1_output_root_mean_squared_error: 0.5584 - val_y2_output_root_mean_squared_error: 0.7401
# Epoch 465/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4531 - y1_output_loss: 0.1500 - y2_output_loss: 0.3018 - y1_output_root_mean_squared_error: 0.3884 - y2_output_root_mean_squared_error: 0.5497 - val_loss: 0.9646 - val_y1_output_loss: 0.3167 - val_y2_output_loss: 0.6240 - val_y1_output_root_mean_squared_error: 0.5727 - val_y2_output_root_mean_squared_error: 0.7979
# Epoch 466/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3532 - y1_output_loss: 0.1163 - y2_output_loss: 0.2361 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4863 - val_loss: 0.7323 - val_y1_output_loss: 0.2123 - val_y2_output_loss: 0.5017 - val_y1_output_root_mean_squared_error: 0.4635 - val_y2_output_root_mean_squared_error: 0.7194
# Epoch 467/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5536 - y1_output_loss: 0.1499 - y2_output_loss: 0.4009 - y1_output_root_mean_squared_error: 0.3884 - y2_output_root_mean_squared_error: 0.6346 - val_loss: 0.7752 - val_y1_output_loss: 0.2060 - val_y2_output_loss: 0.5478 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 0.7514
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3246 - y1_output_loss: 0.1138 - y2_output_loss: 0.2102 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4589 - val_loss: 0.8066 - val_y1_output_loss: 0.2599 - val_y2_output_loss: 0.5334 - val_y1_output_root_mean_squared_error: 0.5116 - val_y2_output_root_mean_squared_error: 0.7381
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4293 - y1_output_loss: 0.1364 - y2_output_loss: 0.2903 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5405 - val_loss: 0.6084 - val_y1_output_loss: 0.1836 - val_y2_output_loss: 0.4127 - val_y1_output_root_mean_squared_error: 0.4335 - val_y2_output_root_mean_squared_error: 0.6484
# Epoch 470/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4278 - y1_output_loss: 0.1389 - y2_output_loss: 0.2874 - y1_output_root_mean_squared_error: 0.3742 - y2_output_root_mean_squared_error: 0.5365 - val_loss: 0.5686 - val_y1_output_loss: 0.1615 - val_y2_output_loss: 0.3970 - val_y1_output_root_mean_squared_error: 0.4042 - val_y2_output_root_mean_squared_error: 0.6366
# Epoch 471/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3176 - y1_output_loss: 0.1073 - y2_output_loss: 0.2160 - y1_output_root_mean_squared_error: 0.3270 - y2_output_root_mean_squared_error: 0.4590 - val_loss: 1.1575 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.9789 - val_y1_output_root_mean_squared_error: 0.4063 - val_y2_output_root_mean_squared_error: 0.9962
# Epoch 472/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3750 - y1_output_loss: 0.1356 - y2_output_loss: 0.2438 - y1_output_root_mean_squared_error: 0.3666 - y2_output_root_mean_squared_error: 0.4905 - val_loss: 1.4154 - val_y1_output_loss: 0.2464 - val_y2_output_loss: 1.1560 - val_y1_output_root_mean_squared_error: 0.5028 - val_y2_output_root_mean_squared_error: 1.0782
# Epoch 473/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3149 - y1_output_loss: 0.1087 - y2_output_loss: 0.2094 - y1_output_root_mean_squared_error: 0.3293 - y2_output_root_mean_squared_error: 0.4544 - val_loss: 0.6868 - val_y1_output_loss: 0.2130 - val_y2_output_loss: 0.4602 - val_y1_output_root_mean_squared_error: 0.4614 - val_y2_output_root_mean_squared_error: 0.6884
# Epoch 474/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3309 - y1_output_loss: 0.1047 - y2_output_loss: 0.2250 - y1_output_root_mean_squared_error: 0.3237 - y2_output_root_mean_squared_error: 0.4755 - val_loss: 0.6887 - val_y1_output_loss: 0.2448 - val_y2_output_loss: 0.4308 - val_y1_output_root_mean_squared_error: 0.5020 - val_y2_output_root_mean_squared_error: 0.6608
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4258 - y1_output_loss: 0.1235 - y2_output_loss: 0.2993 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.5489 - val_loss: 0.7352 - val_y1_output_loss: 0.1755 - val_y2_output_loss: 0.5388 - val_y1_output_root_mean_squared_error: 0.4238 - val_y2_output_root_mean_squared_error: 0.7454
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3860 - y1_output_loss: 0.1189 - y2_output_loss: 0.2651 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.5159 - val_loss: 0.8099 - val_y1_output_loss: 0.1907 - val_y2_output_loss: 0.6000 - val_y1_output_root_mean_squared_error: 0.4379 - val_y2_output_root_mean_squared_error: 0.7862
# Epoch 477/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3420 - y1_output_loss: 0.1175 - y2_output_loss: 0.2232 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.4738 - val_loss: 0.6630 - val_y1_output_loss: 0.1832 - val_y2_output_loss: 0.4684 - val_y1_output_root_mean_squared_error: 0.4272 - val_y2_output_root_mean_squared_error: 0.6932
# Epoch 478/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3342 - y1_output_loss: 0.1109 - y2_output_loss: 0.2210 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4715 - val_loss: 0.5899 - val_y1_output_loss: 0.1570 - val_y2_output_loss: 0.4189 - val_y1_output_root_mean_squared_error: 0.4000 - val_y2_output_root_mean_squared_error: 0.6557
# Epoch 479/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2971 - y1_output_loss: 0.0923 - y2_output_loss: 0.2054 - y1_output_root_mean_squared_error: 0.3043 - y2_output_root_mean_squared_error: 0.4523 - val_loss: 1.3241 - val_y1_output_loss: 0.1841 - val_y2_output_loss: 1.1219 - val_y1_output_root_mean_squared_error: 0.4350 - val_y2_output_root_mean_squared_error: 1.0653
# Epoch 480/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2979 - y1_output_loss: 0.0990 - y2_output_loss: 0.1985 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4467 - val_loss: 0.9165 - val_y1_output_loss: 0.3139 - val_y2_output_loss: 0.5779 - val_y1_output_root_mean_squared_error: 0.5643 - val_y2_output_root_mean_squared_error: 0.7733
# Epoch 481/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3639 - y1_output_loss: 0.1191 - y2_output_loss: 0.2430 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.4940 - val_loss: 0.6302 - val_y1_output_loss: 0.1969 - val_y2_output_loss: 0.4234 - val_y1_output_root_mean_squared_error: 0.4464 - val_y2_output_root_mean_squared_error: 0.6565
# Epoch 482/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2522 - y1_output_loss: 0.0994 - y2_output_loss: 0.1543 - y1_output_root_mean_squared_error: 0.3123 - y2_output_root_mean_squared_error: 0.3933 - val_loss: 0.6887 - val_y1_output_loss: 0.1821 - val_y2_output_loss: 0.5007 - val_y1_output_root_mean_squared_error: 0.4289 - val_y2_output_root_mean_squared_error: 0.7104
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3418 - y1_output_loss: 0.1161 - y2_output_loss: 0.2232 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.4742 - val_loss: 0.6180 - val_y1_output_loss: 0.1761 - val_y2_output_loss: 0.4282 - val_y1_output_root_mean_squared_error: 0.4250 - val_y2_output_root_mean_squared_error: 0.6613
# Epoch 484/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3585 - y1_output_loss: 0.1152 - y2_output_loss: 0.2409 - y1_output_root_mean_squared_error: 0.3407 - y2_output_root_mean_squared_error: 0.4924 - val_loss: 0.6177 - val_y1_output_loss: 0.1596 - val_y2_output_loss: 0.4425 - val_y1_output_root_mean_squared_error: 0.4049 - val_y2_output_root_mean_squared_error: 0.6736
# Epoch 485/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4463 - y1_output_loss: 0.1267 - y2_output_loss: 0.3223 - y1_output_root_mean_squared_error: 0.3558 - y2_output_root_mean_squared_error: 0.5654 - val_loss: 1.2965 - val_y1_output_loss: 0.2332 - val_y2_output_loss: 1.0358 - val_y1_output_root_mean_squared_error: 0.4813 - val_y2_output_root_mean_squared_error: 1.0319
# Epoch 486/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3321 - y1_output_loss: 0.1060 - y2_output_loss: 0.2234 - y1_output_root_mean_squared_error: 0.3271 - y2_output_root_mean_squared_error: 0.4744 - val_loss: 0.5977 - val_y1_output_loss: 0.2063 - val_y2_output_loss: 0.3766 - val_y1_output_root_mean_squared_error: 0.4567 - val_y2_output_root_mean_squared_error: 0.6238
# Epoch 487/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4040 - y1_output_loss: 0.1379 - y2_output_loss: 0.2844 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5193 - val_loss: 4.0366 - val_y1_output_loss: 0.8506 - val_y2_output_loss: 3.1468 - val_y1_output_root_mean_squared_error: 0.9254 - val_y2_output_root_mean_squared_error: 1.7833
# Epoch 488/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5830 - y1_output_loss: 0.1972 - y2_output_loss: 0.3822 - y1_output_root_mean_squared_error: 0.4446 - y2_output_root_mean_squared_error: 0.6208 - val_loss: 0.7472 - val_y1_output_loss: 0.3020 - val_y2_output_loss: 0.4340 - val_y1_output_root_mean_squared_error: 0.5543 - val_y2_output_root_mean_squared_error: 0.6633
# Epoch 489/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3098 - y1_output_loss: 0.0996 - y2_output_loss: 0.2095 - y1_output_root_mean_squared_error: 0.3160 - y2_output_root_mean_squared_error: 0.4582 - val_loss: 0.9345 - val_y1_output_loss: 0.2143 - val_y2_output_loss: 0.6987 - val_y1_output_root_mean_squared_error: 0.4650 - val_y2_output_root_mean_squared_error: 0.8475
# Epoch 490/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2881 - y1_output_loss: 0.1034 - y2_output_loss: 0.1820 - y1_output_root_mean_squared_error: 0.3230 - y2_output_root_mean_squared_error: 0.4286 - val_loss: 0.6456 - val_y1_output_loss: 0.1806 - val_y2_output_loss: 0.4557 - val_y1_output_root_mean_squared_error: 0.4288 - val_y2_output_root_mean_squared_error: 0.6795
# Epoch 491/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.2702 - y1_output_loss: 0.0960 - y2_output_loss: 0.1728 - y1_output_root_mean_squared_error: 0.3111 - y2_output_root_mean_squared_error: 0.4165 - val_loss: 0.5957 - val_y1_output_loss: 0.1879 - val_y2_output_loss: 0.3951 - val_y1_output_root_mean_squared_error: 0.4397 - val_y2_output_root_mean_squared_error: 0.6343
# Epoch 492/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4913 - y1_output_loss: 0.1458 - y2_output_loss: 0.3491 - y1_output_root_mean_squared_error: 0.3807 - y2_output_root_mean_squared_error: 0.5885 - val_loss: 1.3528 - val_y1_output_loss: 0.3398 - val_y2_output_loss: 1.0004 - val_y1_output_root_mean_squared_error: 0.5901 - val_y2_output_root_mean_squared_error: 1.0023
# Epoch 493/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3728 - y1_output_loss: 0.1120 - y2_output_loss: 0.2576 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.5098 - val_loss: 0.5945 - val_y1_output_loss: 0.1839 - val_y2_output_loss: 0.3992 - val_y1_output_root_mean_squared_error: 0.4351 - val_y2_output_root_mean_squared_error: 0.6366
# Epoch 494/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4096 - y1_output_loss: 0.1240 - y2_output_loss: 0.2836 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.5336 - val_loss: 0.6465 - val_y1_output_loss: 0.2051 - val_y2_output_loss: 0.4356 - val_y1_output_root_mean_squared_error: 0.4559 - val_y2_output_root_mean_squared_error: 0.6624
# Epoch 495/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2698 - y1_output_loss: 0.0999 - y2_output_loss: 0.1712 - y1_output_root_mean_squared_error: 0.3173 - y2_output_root_mean_squared_error: 0.4112 - val_loss: 1.3446 - val_y1_output_loss: 0.1686 - val_y2_output_loss: 1.1539 - val_y1_output_root_mean_squared_error: 0.4164 - val_y2_output_root_mean_squared_error: 1.0822
# Epoch 496/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4121 - y1_output_loss: 0.1250 - y2_output_loss: 0.2847 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5348 - val_loss: 0.6670 - val_y1_output_loss: 0.1945 - val_y2_output_loss: 0.4724 - val_y1_output_root_mean_squared_error: 0.4387 - val_y2_output_root_mean_squared_error: 0.6888
# Epoch 497/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2820 - y1_output_loss: 0.1041 - y2_output_loss: 0.1760 - y1_output_root_mean_squared_error: 0.3239 - y2_output_root_mean_squared_error: 0.4209 - val_loss: 0.6560 - val_y1_output_loss: 0.1783 - val_y2_output_loss: 0.4661 - val_y1_output_root_mean_squared_error: 0.4276 - val_y2_output_root_mean_squared_error: 0.6879
# Epoch 498/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2874 - y1_output_loss: 0.1018 - y2_output_loss: 0.1857 - y1_output_root_mean_squared_error: 0.3206 - y2_output_root_mean_squared_error: 0.4297 - val_loss: 0.9057 - val_y1_output_loss: 0.1781 - val_y2_output_loss: 0.6992 - val_y1_output_root_mean_squared_error: 0.4293 - val_y2_output_root_mean_squared_error: 0.8493
# Epoch 499/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2807 - y1_output_loss: 0.1044 - y2_output_loss: 0.1749 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.4189 - val_loss: 0.6659 - val_y1_output_loss: 0.2319 - val_y2_output_loss: 0.4200 - val_y1_output_root_mean_squared_error: 0.4874 - val_y2_output_root_mean_squared_error: 0.6545
# Epoch 500/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3422 - y1_output_loss: 0.1134 - y2_output_loss: 0.2278 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.4794 - val_loss: 0.6464 - val_y1_output_loss: 0.2210 - val_y2_output_loss: 0.4126 - val_y1_output_root_mean_squared_error: 0.4716 - val_y2_output_root_mean_squared_error: 0.6511

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.6464 - y1_output_loss: 0.2212 - y2_output_loss: 0.4189 - y1_output_root_mean_squared_error: 0.4716 - y2_output_root_mean_squared_error: 0.6511
# Loss = 0.6463543768827017, Y1_loss = 0.22124052047729492, Y1_mse = 0.4715876579284668, Y2_loss = 0.41885700821876526, Y2_mse = 0.6511216759681702

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
